# %% [markdown]
# ### Tuple

# %%
my_tuple = (10,30,20,10)
print(my_tuple)    # allow duplicates
print(my_tuple[1]) # indexed
# my_tuple[3] = 40 #immmutable
print(sorted(my_tuple))
# Out:
# (10, 30, 20, 10)
# 30
# [10, 10, 20, 30]
