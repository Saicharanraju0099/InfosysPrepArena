# %%
import random as r
size = 12
password = ''
for i in range(size):
    num = r.randint(1,100)
    char = chr(num)
    password += char
print(password)
# Out:
# (X5A/<B2

# %%
import os 
os.mkdir("Training")
