# %% [markdown]
# ### Comments are just notes for humans. The interpreter ingores them completely

# %% [markdown]
# ### Single Line Comments

# %%
#This is Single Line Comment
x = 10  # This Comment Explains the Variable x

# %% [markdown]
# ### Multiline Comments

# %%
"""
This Line is a Multi Line Comment and it can span multiple lines.
Docstring for Introduction.Comments.ipynb
"""

# %%
# This function adds two numbers
# It takes two parameters, a and b, and returns their sum

# %%
# store the final exam score in variable         -> This is for Long Detailed Explanation
final_exam_score = 95
x = 10                       # This is For Short Explanation
