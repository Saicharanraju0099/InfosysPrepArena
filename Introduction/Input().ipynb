# %%
name = input("Enter Your Name: ")
print("Hello", name, "Welcome to Python Programming")
# Out:
# Hello Sai Welcome to Python Programming

# %%
x = "Apple"
print(x)
# Ask for a value
y = input("Enter a value: ")
print(y)
# Out:
# Apple
# is Fruit
