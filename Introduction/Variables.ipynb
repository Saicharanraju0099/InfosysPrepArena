# %% [markdown]
# ### A Variable in python are labels attached to objects in memory

# %%
name = "Saicharan"
language = "python"
print(name, "is a student")
print(name, "is learning", language)
print(name, "wants to become", language, "expert")
# Out:
# Saicharan is a student
# Saicharan is learning python
# Saicharan wants to become python expert

# %%
name = "Saketh"
language = "Java"
print(name, "is a student")
print(name, "is learning", language)
print(name, "wants to become", language, "expert")
# Out:
# Saketh is a student
# Saketh is learning Java
# Saketh wants to become Java expert

# %%
email = "info@saicharan.com"
email_support = "support@saicharan.com"
print("My email is", email)
print("My support email is", email_support)
website = "www.saicharan.com"
print("My website is", website)
# Out:
# My email is info@saicharan.com
# My support email is support@saicharan.com
# My website is www.saicharan.com
