# %% [markdown]
# ### A Builtin python function that display messages on screen to communicate with users

# %%
print("Hi Python")
print('Hello Python')
# Out:
# Hi Python
# Hello Python

# %%
print("------------------------------------")
print("  Welcome to Python Programming  ")
print("------------------------------------")
# Out:
# ------------------------------------
#   Welcome to Python Programming
# ------------------------------------

# %% [markdown]
# ### Escape Sequence

# %%
print("Hi \"Python\"")
print('Hello \'Python\'')
# Out:
# Hi "Python"
# Hello 'Python'

# %%
print("path: C:\\Users\\saicharan\\Documents\\Python\\Practice") ## in order to print \ we need to use \\
# Out:
# path: C:\Users\saicharan\Documents\Python\Practice

# %%
print("message1 \n")  # \n is used to print in new line
print("message2")
# Out:
# message1
#
# message2

# %%
print("message1\tmessage2") # \t is used to print in tab space
# Out:
# message1	message2

# %%
print("""Your Learning Path:
\t-Python Basics
\t-Data Engineering
\t-AI""")
# Out:
# Your Learning Path:
# 	-Python Basics
# 	-Data Engineering
# 	-AI

# %%
price_shirt = 500
price_pants = 700
quantity_shirt = 2
quantity_pants = 3
total_shirts = price_shirt * quantity_shirt
total_pants = price_pants * quantity_pants
subtotal = total_shirts + total_pants
print("Subtatal: ", subtotal)
discount = 0.25 * subtotal
print("Discount: ", discount)
final_total = subtotal - discount
print("Final Total: ",final_total)
# Out:
# Subtatal:  3100
# Discount:  775.0
# Final Total:  2325.0
