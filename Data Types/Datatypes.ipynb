# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Data Types
a = 5           # int
b = 3.25.       # float
c = "Hello"     # string
d = 'Hi'        # string
e = '12'        # string
f = True        # boolean
g = False       # boolean
h = None        # no value

# %%
text = "string"
number = 30
print(text)
print(type(number))
# Out:
# string
# <class 'int'>
