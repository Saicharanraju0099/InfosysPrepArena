# %% [markdown]
# ### Level 1
# ### Function Basics

# %% [markdown]
# ### Write a function greet() that prints
# ### Hello, Welcome to Python

# %%
def greet():
    print("hello, welcome to python")
    
greet()
# Out:
# hello, welcome to python

# %% [markdown]
# ### Write a function square(num) that returns the square of a number.

# %%
def square(num):
    return num * num
square(3)
# Out:
# 9

# %% [markdown]
# ### Write a function add(a, b) that returns the sum of two numbers.

# %%
def Add(a,b):
    return a + b
Add(2,2)
# Out:
# 4

# %% [markdown]
# ### Write a function is_even(n) that returns True if a number is even, otherwise False.

# %%
def is_even(num):
    if num % 2 == 0:
        return True
    else:
        return False
is_even(24)
# Out:
# True

# %% [markdown]
# ### Write a function largest(a, b, c) that returns the largest of three numbers.

# %%
def largest(a,b,c):
    if a >= b and a >= c:
        return a
    elif b >= a and b >= c:
        return b
    else:
        return c
print(largest(12,13,25))
print(largest(12,12,12))
# Out:
# 25
# 12

# %% [markdown]
# ### Level 2 — Functions + Loops

# %% [markdown]
# ### Write a function sum_numbers(n) that returns the sum from 1 to n.

# %%
def sum_numbers(n):
    n = n * (n+1) // 2
    return n
print(sum_numbers(5))
# Out:
# 15

# %% [markdown]
# ### Write a function factorial(n) that returns the factorial of a number.

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1
    return n * factorial(n-1)        ## 5 * (4 * (3 * (2 * (1))))
print(factorial(5))
# Out:
# 120

# %% [markdown]
# ### Write a function count_vowels(text) that counts vowels in a string.

# %%
def count_vowels(text):
    count = 0
    vowels = "aeiou"

    for char in text:
        if char in vowels.lower():
            count = count + 1
    return count
print(count_vowels("Saicharan"))
# Out:
# 4

# %% [markdown]
# ### Write a function reverse_string(text) that returns the reversed string.

# %%
def reverse_string(text):
    reversed_text = ""
    print(f"Starting with: '{text}'\n") # Initial message

    for char in text:
        # We add the new character to the FRONT
        reversed_text = char + reversed_text
        print(f"Added '{char}' -> Current result: '{reversed_text}'")

    return reversed_text

# Calling the function
final_result = reverse_string("ABC")
print(f"\nFinal reversed string: {final_result}")
# Out:
# Starting with: 'ABC'
#
# Added 'A' -> Current result: 'A'
# Added 'B' -> Current result: 'BA'
# Added 'C' -> Current result: 'CBA'
#
# Final reversed string: CBA

# %% [markdown]
# ### Write a function multiplication_table(n) that prints the table of a number up to 10.

# %%
def multiplication_table(n):
    for i in range(1,11):
        result = n * i
        print(f"{n} x {i} = {result}")
multiplication_table(7)
# Out:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70

# %% [markdown]
# ### Level 3 — Functions + Lists

# %% [markdown]
# ### Write a function find_max(lst) that returns the largest number in a list.

# %%
def find_max(lst):
    if not lst:
        return None
    
    ## Start by assuming the first item is the largest
    largest = lst[0]
    for number in lst:
        if number > largest:
            largest = number
            
    return largest
# 1. Define a list of numbers
my_numbers = [10, 45, 2, 99, 14]

# 2. Call the function and store the result
max_value = find_max(my_numbers)

# 3. Display the result
print(max_value)  # Output: 99
# Out:
# 99

# %% [markdown]
# ### Write a function count_even(lst) that counts how many even numbers are in a list.

# %%
def count_even(lst):
    count = 0
    for number in lst:
        ## Check if the remainder is 0 when divide by zero
        if number % 2 == 0:
            count = count + 1
    return count
number = [1, 2, 3, 4, 5, 6]
print(count_even(number))
# Out:
# 3

# %% [markdown]
# ### Write a function remove_duplicates(lst) that returns a list with duplicates removed.

# %%
def remove_duplicates(lst):
    unique_list = []
    for item in lst:
        if item not in unique_list:
            unique_list.append(item)
    return unique_list
numbers = [2,4,3,5,7,6,2,3,1,8,9,2]
print(remove_duplicates(numbers))
# Out:
# [2, 4, 3, 5, 7, 6, 1, 8, 9]
